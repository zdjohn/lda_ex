# %%
# %%html
# <style>
# div.output_subarea pre {
#     white-space: pre;
# }
# </style>
# Out:
# <style>
# div.output_subarea pre {
#     white-space: pre;
# }
# </style>

# %% [markdown]
# # Unsupervised clustering approaches
#
# For unsupervised learning for clustering, there are 3 potential approaches can be applicable here.
# 1. PCA + K-mean
# 2. Graph based embedding
# 3. LDA
#
# **#1:** The features presented for each product are mostly categorical instead of value variance. Considering this is as a classification problem, PCA may not yield the best result in this senario.
#
# **#2** Grpah based embedding approach, could be an interesting one. However, the support for graph embedding is a bit lagging with pyspark mllib. `node2vec` maybe possible with work around, while `graphSage` would require implementing everything alsmost from scratch. (if time allows, I may revisit this later)
#
# **#3** Lastly, LDA, a NLP based approachm, where we treat the catrogorization as a topic clustering problem.
#
# Finally I decided to use #3 due to time and effort constraint. Following are clustering experiment:

# %%
import findspark; findspark.init()
from os import environ, listdir, path, getcwd
from pathlib import Path
import numpy as np
import pandas as pd
import pyspark.sql.functions as F
from pyspark.sql import Window
from pyspark.ml.clustering import LDA, LocalLDAModel, LDAModel
from clustering_ex import utils, udf

# %% [markdown]
# ### Transformed data set base on differnt K value
# change the `K` value to see different clustering output. I experimented different `K` values, from 5~8, with different hyper-parameters setting. Different output can be found in `s3://zip-ex/output/`
#
# **So far, `K=6` produces best clustering results.**

# %%
bucket_by_k ={
    '5':'output/1622372691_550',
    '6':'output/1622377560_65050',
    '7':'output/1622375164_7-6956370388595972856',
}
K='6'
bucket_prefix = bucket_by_k[K]

# %% [markdown]
# ### Initial item data exloration and analysis (DEA)
#
# The things I learned from DEA below is: the same product with exact same `product name` could have multiple `item code`s, sold under different `brands` `categories` by differet `retailers`.
#
# **Here, I am making the assumption of product with same `product_name` are the same across the given dataset.**

# %%
environ['PYSPARK_SUBMIT_ARGS'] = "--packages=com.amazonaws:aws-java-sdk:1.11.900,org.apache.hadoop:hadoop-aws:3.2.0 pyspark-shell"
environ['DEBUG'] = "1"
environ['PYSPARK_PYTHON']=f'{Path(getcwd())}/.tox/dev/bin/python'
session, logger, settings = utils.start_spark()
# Out:
# getting spark session
# spark session created

# %%
item_df = session.read.parquet(f'{settings["base_bucket"]}/{bucket_prefix}/item_df.parquet')
tf_idf_feature_df = session.read.parquet(f'{settings["base_bucket"]}/{bucket_prefix}/item_tf_idf_df.parquet')
item_df.describe(['price','code_count','category_count','retrailer_count','brand_count']).show()
# Out:
# +-------+-----------------+------------------+------------------+-------------------+------------------+
# |summary|            price|        code_count|    category_count|    retrailer_count|       brand_count|
# +-------+-----------------+------------------+------------------+-------------------+------------------+
# |  count|            21355|             21415|             21415|              21415|             21415|
# |   mean|278.1060359519797| 1.252860144758347| 1.884753677328975| 1.0146626196591175|1.0285314032220407|
# | stddev|1107.255797879404|2.2371720839549876|0.7366245146089858|0.15332252187577486|0.4777464588368348|
# |    min|             1.45|                 1|                 1|                  1|                 1|
# |    max|          78737.0|               186|                11|                  8|                45|
# +-------+-----------------+------------------+------------------+-------------------+------------------+

# %%
item_overview = item_df.select(
    F.countDistinct('product_name').alias('product_distinct'),
    F.size(udf.merge_lists(F.collect_set('retailers'))).alias('retailers_distinct'), 
    F.size(udf.merge_lists(F.collect_set('categories'))).alias('categories_distinct'), 
    F.size(udf.merge_lists(F.collect_set('brands'))).alias('brands_distinct')
)
item_overview.show()
# Out:
# +----------------+------------------+-------------------+---------------+
# |product_distinct|retailers_distinct|categories_distinct|brands_distinct|
# +----------------+------------------+-------------------+---------------+
# |           21415|                87|                212|           2178|
# +----------------+------------------+-------------------+---------------+

# %% [markdown]
# ## LDA based topic categoies, findings and insights
#
# Roughly, we can see the LDA model classifies the dataset in to 6 categories:
#
# - **TOPIC 0,** Designer fashion brands clothing
# - **TOPIC 1,** Jumpsuits, Rompers, women's fashion
# - **TOPIC 2,** Sports ware
# - **TOPIC 3,** Fashion Accessories
# - **TOPIC 4,** Face masks
# - **TOPIC 5,** Skincare, Cosmetics
#
# Below are couple interesting findings after we looking depper into item data in each category.
#
# **1 different "polo" brands clustered in different topics**
#
# Though "Polo" shows up in both *Topic 0* and *Topic 2* a lot, when we look into the brands information in each topic, we can start tell the differnce.
#
# i.e. Luxury/designer brands, such as, "burberry", "givenchy", "saint-laurent", etc. are mostly clustered inside *Topic 0* for "polo" related products.
#
# Meanwhile, in *Topic 2*, the brands we see are mostly "nike", "adidas", "puma" (sports brands).
#
# **2. "Face Masks" means different things across topics**
#
# We also find "Face Masks" is showing up on both *Topic 4 and 5*.
#
# However, when we looking into corresponding topics, we find the "face masks" means skin care products, such as "Forever Glow Anti-Aging Face Mask 5 Pack" in *Topic 5*.
#
# While in *Topic 4*, it means differnt types of protective/fashion face masks due to recent COVID-19 event.

# %% [markdown]
# **Sample Top 10 products in each category topic**

# %%
item_topic_df = session.read.parquet(f'{settings["base_bucket"]}/{bucket_prefix}/item_topic_df.parquet')
windowSpec  = Window.partitionBy("topic").orderBy(F.col('score').desc())
top_10_samples = item_topic_df.withColumn('rank', F.row_number().over(windowSpec)
                                 ).where('rank<=10').sort('topic'
                                                        ).select('topic','product_name','categories', 'brands')
top_10_samples.show(60,False)
# Out:
# +-----+-----------------------------------------------------------------+--------------------------------------------------------------------------+-----------------------------------+
# |topic|product_name                                                     |categories                                                                |brands                             |
# +-----+-----------------------------------------------------------------+--------------------------------------------------------------------------+-----------------------------------+
# |0    |Black Triptych Bolt Polo                                         |[Polos, Short Sleeve]                                                     |[neil-barrett]                     |
# |0    |Brown Knitted Pique Polo                                         |[Polos, Long Sleeve]                                                      |[bottega-veneta]                   |
# |0    |Black and Beige Merino Wool Blakeford Polo                       |[Polos, Short Sleeve]                                                     |[burberry]                         |
# |0    |Black Pique Long Sleeve Polo                                     |[Polos, Long Sleeve]                                                      |[lacoste, burberry, bottega-veneta]|
# |0    |Black Spaghetti Charm Button Polo                                |[Polos, Short Sleeve]                                                     |[paul-smith-50th-anniversary]      |
# |0    |Beige Knit Stripe Polo                                           |[Polos, Long Sleeve]                                                      |[drole-de-monsieur]                |
# |0    |Orange and Multicolor Striped Polo                               |[Polos, Short Sleeve]                                                     |[missoni]                          |
# |0    |Black 4G Band Polo                                               |[Tennis, Polos, Short Sleeve]                                             |[givenchy]                         |
# |0    |Black Skull Polo                                                 |[Polos, Short Sleeve]                                                     |[alexander-mcqueen]                |
# |0    |Orange and Burgundy Pleated Polo                                 |[Polos, Short Sleeve]                                                     |[burberry]                         |
# |1    |Parker Romper                                                    |[Rompers]                                                                 |[pistola, rails]                   |
# |1    |Gia Romper                                                       |[Rompers]                                                                 |[lovers-friends]                   |
# |1    |DODO BAR OR Black / Red Floral Violetta Jumpsuit                 |[Jumpsuit]                                                                |[dodo-bar-or]                      |
# |1    |x REVOLVE Marcello Jumpsuit                                      |[Jumpsuits, Long Sleeve]                                                  |[house-of-harlow-1960]             |
# |1    |Rocky Jumpsuit                                                   |[Jumpsuits]                                                               |[lacademie]                        |
# |1    |Plateau Jumpsuit                                                 |[Jumpsuits]                                                               |[nbd]                              |
# |1    |Jill Romper                                                      |[Rompers]                                                                 |[lovers-friends]                   |
# |1    |Margo Romper                                                     |[Rompers]                                                                 |[lovers-friends]                   |
# |1    |Lara Jumpsuit                                                    |[Jumpsuits]                                                               |[nbd]                              |
# |1    |Fiona Jumpsuit                                                   |[Jumpsuits]                                                               |[lovers-friends]                   |
# |2    |Men's Abstract Tipped Polo Shirt in White Size Small 100% Cotton |[Athletic, Polo Shirt]                                                    |[fred-perry]                       |
# |2    |Men Cotton Pique Polo Shirt Solid - Polo - Palan - Yellow        |[Short Sleeves, Short-Sleeved, Polos, Polo Shirt]                         |[vilebrequin]                      |
# |2    |Men Cotton Pique Polo Shirt Solid - Polos - Palan - Yellow       |[Short Sleeves, Short-Sleeved, Polos, Polo Shirt]                         |[vilebrequin]                      |
# |2    |Men Cotton Pique Polo Shirt Solid - Polo - Palan - Blue          |[Short Sleeves, Short-Sleeved, Polos, Polo Shirt]                         |[vilebrequin]                      |
# |2    |Men's Scuderia Ferrari Race Polo Shirt in White/ White Size Small|[Track, Athletic, Polo Shirt]                                             |[puma]                             |
# |2    |Men's Stripe Button Down Polo Shirt in White Size Large          |[Athletic, Polo Shirt]                                                    |[nicce]                            |
# |2    |Men's Stripe Button Down Polo Shirt in White/White Size X-Large  |[Athletic, Polo Shirt]                                                    |[nicce]                            |
# |2    |Men's Slim Fit Polo Shirt in Blue/Blue Size Large 100% Cotton    |[Shirts, Polo Shirt]                                                      |[lacoste]                          |
# |2    |Men's Scuderia Ferrari Race Polo Shirt in Grey Size Large        |[Track, Athletic, Polo Shirt]                                             |[puma]                             |
# |2    |Men Cotton Pique Polo Shirt Solid - Polos - Palan - Blue         |[Short Sleeves, Short-Sleeved, Polos, Polo Shirt]                         |[vilebrequin]                      |
# |3    |The Camellia Barrette                                            |[Hair Clip, Accessories Hair, Barrette]                                   |[adiba]                            |
# |3    |Champagne & Mocha Satin Scrunchie Bundle                         |[Scrunchies, Accessories Hair]                                            |[clara-lifestyle]                  |
# |3    |Pistachio Green Thin Silk Scarf                                  |[Accessories Hair]                                                        |[the-pathline]                     |
# |3    |The Calla Barrette                                               |[Hair Clip, Accessories Hair, Barrette]                                   |[adiba]                            |
# |3    |Mustard Yellow Thin Silk Scarf                                   |[Accessories Hair]                                                        |[the-pathline]                     |
# |3    |Satin Scrunchie Bundle - Champagne, Olive & Mocha                |[Scrunchies, Accessories Hair]                                            |[clara-lifestyle]                  |
# |3    |Mocha & Olive Satin Scrunchie Bundle                             |[Scrunchies, Accessories Hair]                                            |[clara-lifestyle]                  |
# |3    |So Golden Satin Scrunchie                                        |[Scrunchies, Accessories Hair]                                            |[clara-lifestyle]                  |
# |3    |Gold Rose Pure Silk Jacquard Scrunchie                           |[Hair Accessories, Accessories Hair, Scrunchies]                          |[gisy]                             |
# |3    |Rose Lemonade Thin Silk Scarf                                    |[Accessories Hair]                                                        |[the-pathline]                     |
# |4    |Pearl-Embellished Face Mask 3-Pack                               |[Face Masks]                                                              |[lizzie-fortunato]                 |
# |4    |Floral Jersey Face Mask 3-Pack                                   |[Face Masks]                                                              |[intermix]                         |
# |4    |Disposable Face Mask 7-Pack                                      |[Face Masks]                                                              |[evolvetogether-tm]                |
# |4    |Upcycled Face Mask 2-Pack                                        |[Face Masks]                                                              |[re-done]                          |
# |4    |Never Say Never Lace Face Mask                                   |[Face Masks]                                                              |[cosabella]                        |
# |4    |Disposable Face Mask 30-Pack                                     |[Face Masks]                                                              |[evolvetogether-tm]                |
# |4    |Upcycled Face Mask                                               |[Face Mask]                                                               |[re-done]                          |
# |4    |Hamilton Playsuit in Black                                       |[Playsuit]                                                                |[showpo]                           |
# |4    |Never Say Never V Face Mask                                      |[Face Masks]                                                              |[cosabella]                        |
# |4    |Don't Spray It Floral Face Mask                                  |[Face Mask]                                                               |[mother]                           |
# |5    |All About Acne Kit                                               |[Acne Treatment, Sets, Sunscreen, Face Oil, Salicylic Acid, Kit, Cleanser]|[sunday-riley]                     |
# |5    |Universal C Eye Perfector                                        |[Eye Care]                                                                |[beautystat-cosmetics]             |
# |5    |R+R Mask                                                         |[Face Masks]                                                              |[summer-fridays]                   |
# |5    |Peptide Antioxidant Hydra-Serum                                  |[Serum]                                                                   |[elemis]                           |
# |5    |FirmX 360 Eye Renewal                                            |[Eye Care]                                                                |[peter-thomas-roth]                |
# |5    |U.F.O. Ultra-Clarifying Face Oil                                 |[Nourish, Treatment, Face Oils, Salicylic Acid]                           |[sunday-riley]                     |
# |5    |Face Hero Face Oil                                               |[Facial, Face Oils, Face Cream]                                           |[go-to]                            |
# |5    |Meso Infusion Collector's Edition                                |[Face Masks, Peel]                                                        |[111skin]                          |
# |5    |Marula Resurrection Eye Cream                                    |[Eye Care]                                                                |[african-botanics]                 |
# |5    |Prevage Intensive Daily Serum Set (Worth £220.38)                |[Serum, Anti-Aging]                                                       |[elizabeth-arden]                  |
# +-----+-----------------------------------------------------------------+--------------------------------------------------------------------------+-----------------------------------+

# %% [markdown]
# **Topic item samples maps to product category**

# %%
sample_category_by_topic = top_10_samples.groupBy('topic'
                                                 ).agg(udf.merge_lists(F.collect_set('categories')).alias('distinct_category')
                                                       ,udf.merge_lists(F.collect_set('brands')).alias('distinct_brands'))
sample_category_by_topic.sort('topic').show(truncate=False)
# Out:
# +-----+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------+
# |topic|distinct_category                                                                                                                                                           |distinct_brands                                                                                                                        |
# +-----+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------+
# |0    |[Tennis, Long Sleeve, Polos, Short Sleeve]                                                                                                                                  |[lacoste, missoni, givenchy, burberry, bottega-veneta, alexander-mcqueen, paul-smith-50th-anniversary, neil-barrett, drole-de-monsieur]|
# |1    |[Jumpsuits, Jumpsuit, Long Sleeve, Rompers]                                                                                                                                 |[lovers-friends, house-of-harlow-1960, nbd, rails, pistola, lacademie, dodo-bar-or]                                                    |
# |2    |[Track, Athletic, Short-Sleeved, Short Sleeves, Shirts, Polo Shirt, Polos]                                                                                                  |[vilebrequin, lacoste, puma, fred-perry, nicce]                                                                                        |
# |3    |[Hair Accessories, Hair Clip, Accessories Hair, Barrette, Scrunchies]                                                                                                       |[gisy, adiba, clara-lifestyle, the-pathline]                                                                                           |
# |4    |[Face Mask, Face Masks, Playsuit]                                                                                                                                           |[lizzie-fortunato, mother, intermix, re-done, showpo, evolvetogether-tm, cosabella]                                                    |
# |5    |[Acne Treatment, Cleanser, Sets, Face Cream, Anti-Aging, Sunscreen, Face Masks, Face Oil, Salicylic Acid, Treatment, Peel, Kit, Facial, Nourish, Eye Care, Face Oils, Serum]|[go-to, 111skin, peter-thomas-roth, elemis, sunday-riley, elizabeth-arden, african-botanics, beautystat-cosmetics, summer-fridays]     |
# +-----+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------+

# %% [markdown]
# ## Data Visualization with LDAvis
#
# **NOTE: the number insde the circle are not as same as the tiopic number used above. They are ranked based on topic impact (a pyLDAvis implementaion)**

# %%
output_bucket = f"{settings['base_bucket']}/{bucket_prefix}"
stats = utils.read_lda_vis_data_s3(settings['base_bucket'], f"{bucket_prefix}/lda_vis")
import pyLDAvis
pyLDAvis.enable_notebook()
lda_vis = pyLDAvis.prepare(**stats)
pyLDAvis.display(lda_vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el3355341405007728744968049999275"></div>
# <script type="text/javascript">
#
# var ldavis_el3355341405007728744968049999275_data = {"mdsDat": {"x": [0.30103141076161244, -0.3446135846801932, -0.040401196248341854, 0.10601391553929888, -0.13326511581702985, 0.11123457044465372], "y": [-0.2159513423906179, -0.16478256026854934, 0.19885027666669358, 0.12069867224169657, 0.013685102928370252, 0.04749985082240728], "topics": [1, 2, 3, 4, 5, 6], "cluster": [1, 1, 1, 1, 1, 1], "Freq": [29.078417876091777, 24.870214936615216, 13.212177429771726, 11.746151305034907, 11.70639991844336, 9.386638534043016]}, "tinfo": {"Term": ["karl", "skin", "lagerfeld", "padded", "puffer", "ikonik", "crew", "polo", "extract", "oil", "mask", "jumpsuit", "serum", "shirt", "ingredients", "acid", "use", "face", "hair", "pockets", "waist", "collar", "neckline", "oz", "stores", "number", "shipping", "logo", "appearance", "back", "hyaluronic", "antioxidant", "extract", "seed", "buy", "destination", "serum", "leading", "extracts", "hydration", "ingredients", "end", "hydrating", "oil", "acid", "area", "radiant", "formula", "skin's", "luxury", "complexion", "latest", "oz", "actual", "vitamin", "visibly", "directions", "aging", "packaging", "formulated", "skin", "eye", "facial", "appearance", "moisture", "flower", "wrinkles", "treatment", "cream", "helps", "lines", "use", "water", "gently", "fine", "types", "natural", "apply", "help", "face", "products", "mask", "karl", "puffer", "lagerfeld", "ikonik", "padded", "crew", "supplier", "rib", "number", "stores", "name", "available", "pique", "knit", "tonal", "sleeve", "stripes", "twobutton", "vented", "stripe", "spread", "stretchy", "threebutton", "style", "styled", "pattern", "cuffs", "performance", "color", "romper", "placket", "front", "collar", "polo", "white", "long", "logo", "tshirtcolor", "crewneck", "legs", "shell", "pockets", "belt", "fitted", "sleeveless", "wideleg", "crepe", "china", "hip", "neckline", "cropped", "hidden", "jumpsuit", "waist", "zipper", "leg", "shoulder", "bodice", "inseam", "spandex", "polyester", "v", "viscose", "'", "model", "length", "seam", "zip", "side", "wide", "back", "imported", "tie", "closure", "button", "silhouette", "size", "front", "clean", "dry", "fabric", "wash", "style", "jumpsuitwomen", "return", "filter", "returns", "equipment", "orders", "ear", "washable", "covid", "note", "nonmedical", "faqs", "sale", "final", "grade", "nose", "reusable", "masks", "medical", "place", "due", "head", "loops", "item", "information", "us", "personal", "protective", "days", "layers", "love", "shipping", "mask", "protection", "please", "face", "product", "fabric", "easy", "adjustable", "made", "care", "details", "wash", "one", "men's", "piqu\u00e9", "shirt", "contrasting", "embroidery", "m", "pullover", "male", "ribbed", "regular", "group", "gender", "slim", "striped", "adult", "classic", "jersey", "buttons", "blue", "solid", "polo", "wool", "contrast", "chest", "logo", "fit", "wears", "collar", "breathable", "navy", "placket", "embroidered", "threebutton", "print", "white", "size", "color", "spread", "cuffs", "style", "made", "crystal", "hair", "clip", "gold", "crystals", "statement", "leather", "faux", "pink", "touch", "elegant", "headband", "add", "beautiful", "perfect", "metal", "set", "handmade", "silk", "way", "accessories", "velvet", "little", "pack", "material", "outfit", "finished", "wear", "piece", "chic", "also", "look", "designed", "made", "style", "soft", "lightweight"], "Freq": [1279485316.0, 1272751276.0, 640257193.0, 645850589.0, 639767807.0, 639789648.0, 644460499.0, 451790504.0, 526116566.0, 542104802.0, 453239607.0, 326668624.0, 400678496.0, 222588420.0, 368208257.0, 349004479.0, 490525785.0, 385900573.0, 162890191.0, 196466924.0, 203390718.0, 263857067.0, 198320701.0, 275442511.0, 385378992.0, 392039336.0, 211545798.0, 237994074.0, 270902269.0, 266834930.0, 136254310.47776964, 121577175.78324874, 523694845.6618494, 221600917.41757935, 113002425.63130033, 111283525.16925304, 398077681.79428536, 120960926.97005239, 111404177.13389404, 161267952.0797097 ...
